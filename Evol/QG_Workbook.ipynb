# %% [markdown]
# # QG Workbook

# %% [markdown]
# In this notebook I'm translating the Excel code written by Dr. Curt Lively into Python.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
mu, sigma = 10, 3
x = mu + sigma*np.random.randn(10000)

# %%
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ Values \ Before \ Selection:}\ \mu=10,\ \sigma=3$')
plt.axis([0, 20, 0, 0.15])
plt.grid(True)

plt.show()

# %%
S = 2
h = 0.5
mu1, sigma1 = h*S + mu, sigma/2
x1 = mu1 + sigma1*np.random.randn(10000)

# %%
n1, bins1, patches1 = plt.hist(x1, 50, normed=1, facecolor='green', alpha=0.75)
y1 = mlab.normpdf( bins, mu1, sigma1)
l1 = plt.plot(bins, y1, 'r--', linewidth=1)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ Values \ After \ Selection:}\ \mu=h*S+10,\ \sigma=3/2$')
plt.axis([0, 20, 0, 0.45])
plt.grid(True)

plt.show()

# %% [markdown]
# I'm uncertain why sigma is divided by 2.
